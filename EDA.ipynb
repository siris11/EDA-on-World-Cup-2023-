# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/CWC23_all_innings.csv")

# %%
df.shape
# Out:
# (1408, 20)

# %%
df.columns
# Out:
# Index(['team', 'player', 'bat_or_bowl', 'bb_bf', 'runs', 'wkts',
#        'wicketball_prob', 'runs_per_ball', 'opposition', 'ground',
#        'start_date', 'overs', 'mdns', 'econ', 'inns', '4s', '6s', 'sr',
#        'not_out', 'mins'],
#       dtype='object')

# %%
df.head()
# Out:
#   team                     player bat_or_bowl  bb_bf  runs  wkts  \
# 0  PAK  Shaheen Shah Afridi (PAK)        bowl     60    45   3.0
# 1  ENG            DJ Willey (ENG)        bowl     60    45   3.0
# 2   NZ              MJ Henry (NZ)        bowl     60    48   3.0
# 3   NZ           LH Ferguson (NZ)        bowl     60    49   3.0
# 4  AFG           Noor Ahmad (AFG)        bowl     60    49   3.0
#
#    wicketball_prob  runs_per_ball      opposition     ground start_date  \
# 0             0.05       0.750000  v South Africa    Chennai  27-Oct-23
# 1             0.05       0.750000         v India    Lucknow  29-Oct-23
# 2             0.05       0.800000       v England  Ahmedabad   5-Oct-23
# 3             0.05       0.816667    v Bangladesh    Chennai  13-Oct-23
# 4             0.05       0.816667      v Pakistan    Chennai  23-Oct-23
#
#    overs  mdns  econ  inns  4s  6s  sr  not_out  mins
# 0   10.0   0.0   4.5     2 NaN NaN NaN      NaN   NaN
# 1   10.0   2.0   4.5     1 NaN NaN NaN      NaN   NaN
# 2   10.0   1.0   4.8     1 NaN NaN NaN      NaN   NaN
# 3   10.0   0.0   4.9     1 NaN NaN NaN      NaN   NaN
# 4   10.0   0.0   4.9     1 NaN NaN NaN      NaN   NaN

# %%
df.tail()
# Out:
#      team            player bat_or_bowl  bb_bf  runs  wkts  wicketball_prob  \
# 1403   NZ   MJ Santner (NZ)        bowl     60    51   0.0              0.0
# 1404  AUS     A Zampa (AUS)        bowl     42    55   0.0              0.0
# 1405   NZ   R Ravindra (NZ)        bowl     42    60   0.0              0.0
# 1406  IND   RA Jadeja (IND)        bowl     60    63   0.0              0.0
# 1407   NZ  LH Ferguson (NZ)        bowl     48    65   0.0              0.0
#
#       runs_per_ball      opposition        ground start_date  overs  mdns  \
# 1403       0.850000         v India      Wankhede  15-Nov-23   10.0   1.0
# 1404       1.309524  v South Africa  Eden Gardens  16-Nov-23    7.0   0.0
# 1405       1.428571         v India      Wankhede  15-Nov-23    7.0   0.0
# 1406       1.050000   v New Zealand      Wankhede  15-Nov-23   10.0   0.0
# 1407       1.354167         v India      Wankhede  15-Nov-23    8.0   0.0
#
#       econ  inns  4s  6s  sr  not_out  mins
# 1403  5.10     1 NaN NaN NaN      NaN   NaN
# 1404  7.85     1 NaN NaN NaN      NaN   NaN
# 1405  8.57     1 NaN NaN NaN      NaN   NaN
# 1406  6.30     2 NaN NaN NaN      NaN   NaN
# 1407  8.12     1 NaN NaN NaN      NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   team             1408 non-null   object
#  1   player           1408 non-null   object
#  2   bat_or_bowl      1408 non-null   object
#  3   bb_bf            1408 non-null   int64
#  4   runs             1408 non-null   int64
#  5   wkts             562 non-null    float64
#  6   wicketball_prob  1408 non-null   float64
#  7   runs_per_ball    1408 non-null   float64
#  8   opposition       1408 non-null   object
#  9   ground           1408 non-null   object
#  10  start_date       1408 non-null   object
#  11  overs            562 non-null    float64
#  12  mdns             562 non-null    float64
#  13  econ             562 non-null    float64
#  14  inns             1408 non-null   int64
#  15  4s               846 non-null    float64
#  16  6s               846 non-null    float64
#  17  sr               846 non-null    float64
#  18  not_out          846 non-null    float64
#  19  mins             846 non-null    float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 220.1+ KB

# %%
df.describe()
# Out:
#              bb_bf         runs         wkts  wicketball_prob  runs_per_ball  \
# count  1408.000000  1408.000000  1408.000000      1408.000000    1408.000000
# mean     35.305398    33.237216     0.480824         0.070574       0.898755
# std      25.248709    28.056329     0.959552         0.152535       0.471051
# min       0.000000     0.000000     0.000000         0.000000       0.000000
# 25%      13.750000    11.000000     0.000000         0.010724       0.621350
# 50%      32.000000    29.000000     0.000000         0.032258       0.879005
# 75%      54.000000    49.000000     1.000000         0.062500       1.130819
# max     143.000000   201.000000     7.000000         1.000000       6.000000
#
#              overs         mdns         econ         inns           4s  \
# count  1408.000000  1408.000000  1408.000000  1408.000000  1408.000000
# mean      8.827592     0.128551     6.751268     1.470881     1.565341
# std       2.142274     0.374407     1.706750     0.499329     2.752525
# min       0.300000     0.000000     1.350000     1.000000     0.000000
# 25%       8.300000     0.000000     5.797486     1.000000     0.000000
# 50%      10.000000     0.000000     6.817255     1.000000     0.000000
# 75%      10.000000     0.000000     7.960882     2.000000     2.000000
# max      10.000000     3.000000    16.000000     2.000000    21.000000
#
#                 6s           sr      not_out        mins
# count  1408.000000  1408.000000  1408.000000  1408.00000
# mean      0.451705    83.716596     0.090909    42.72104
# std       1.222484    40.666559     0.287582    32.22059
# min       0.000000     0.000000     0.000000     1.00000
# 25%       0.000000    73.520000     0.000000    22.00000
# 50%       0.000000    83.716596     0.000000    42.72104
# 75%       0.000000    89.120000     0.000000    42.72104
# max      11.000000   600.000000     1.000000   217.00000

# %%
df.isnull().sum()
# Out:
# team                 0
# player               0
# bat_or_bowl          0
# bb_bf                0
# runs                 0
# wkts               846
# wicketball_prob      0
# runs_per_ball        0
# opposition           0
# ground               0
# start_date           0
# overs              846
# mdns               846
# econ               846
# inns                 0
# 4s                 562
# 6s                 562
# sr                 562
# not_out            562
# mins               562
# dtype: int64

# %%
cat = df.select_dtypes(include="object").columns
cat
# Out:
# Index(['team', 'player', 'bat_or_bowl', 'opposition', 'ground', 'start_date'], dtype='object')

# %%
df["not_out"].unique()
# Out:
# array([nan,  1.,  0.])

# %%
df["overs"]=df["overs"].fillna(df["overs"].interpolate())
df["mdns"]=df["mdns"].fillna(df["mdns"].interpolate())
df["econ"]=df["econ"].fillna(df["econ"].interpolate())

df["sr"]=df["sr"].fillna(df["sr"].mean())
df["mins"]=df["mins"].fillna(df["mins"].mean())

# %%
from sklearn.impute import SimpleImputer

wkts_impute = SimpleImputer(strategy="most_frequent")
df["wkts"] = wkts_impute.fit_transform(df[["wkts"]])

not_out_impute =SimpleImputer(strategy="most_frequent")
df["not_out"] =not_out_impute.fit_transform(df[["not_out"]])

four_impute =SimpleImputer(strategy="most_frequent")
df["4s"] =four_impute.fit_transform(df[["4s"]])

sixs_impute =SimpleImputer(strategy="most_frequent")
df["6s"] =sixs_impute.fit_transform(df[["6s"]])

# %%
df.isnull().sum()
# Out:
# team               0
# player             0
# bat_or_bowl        0
# bb_bf              0
# runs               0
# wkts               0
# wicketball_prob    0
# runs_per_ball      0
# opposition         0
# ground             0
# start_date         0
# overs              0
# mdns               0
# econ               0
# inns               0
# 4s                 0
# 6s                 0
# sr                 0
# not_out            0
# mins               0
# dtype: int64

# %%
df.head()
# Out:
#   team                     player bat_or_bowl  bb_bf  runs  wkts  \
# 0  PAK  Shaheen Shah Afridi (PAK)        bowl     60    45   3.0
# 1  ENG            DJ Willey (ENG)        bowl     60    45   3.0
# 2   NZ              MJ Henry (NZ)        bowl     60    48   3.0
# 3   NZ           LH Ferguson (NZ)        bowl     60    49   3.0
# 4  AFG           Noor Ahmad (AFG)        bowl     60    49   3.0
#
#    wicketball_prob  runs_per_ball      opposition     ground start_date  \
# 0             0.05       0.750000  v South Africa    Chennai  27-Oct-23
# 1             0.05       0.750000         v India    Lucknow  29-Oct-23
# 2             0.05       0.800000       v England  Ahmedabad   5-Oct-23
# 3             0.05       0.816667    v Bangladesh    Chennai  13-Oct-23
# 4             0.05       0.816667      v Pakistan    Chennai  23-Oct-23
#
#    overs  mdns  econ  inns   4s   6s         sr  not_out      mins
# 0   10.0   0.0   4.5     2  0.0  0.0  83.716596      0.0  42.72104
# 1   10.0   2.0   4.5     1  0.0  0.0  83.716596      0.0  42.72104
# 2   10.0   1.0   4.8     1  0.0  0.0  83.716596      0.0  42.72104
# 3   10.0   0.0   4.9     1  0.0  0.0  83.716596      0.0  42.72104
# 4   10.0   0.0   4.9     1  0.0  0.0  83.716596      0.0  42.72104

# %% [markdown]
# ## How many teams

# %%
df["team"].unique()
# Out:
# array(['PAK', 'ENG', 'NZ', 'AFG', 'NED', 'BAN', 'SA', 'SL', 'AUS', 'IND'],
#       dtype=object)

# %% [markdown]
# ## which team won by scoring the max runs

# %%
df.iloc[df["runs"].idxmax()]
# Out:
# team                            AUS
# player             GJ Maxwell (AUS)
# bat_or_bowl                     bat
# bb_bf                           128
# runs                            201
# wkts                            0.0
# wicketball_prob                 0.0
# runs_per_ball                1.5703
# opposition            v Afghanistan
# ground                     Wankhede
# start_date                 7-Nov-23
# overs                          10.0
# mdns                            0.0
# econ                        8.99538
# inns                              2
# 4s                             21.0
# 6s                             10.0
# sr                           157.03
# not_out                         1.0
# mins                          181.0
# Name: 501, dtype: object

# %%
df.iloc[df["runs"].idxmin()]
# Out:
# team                              BAN
# player             Taskin Ahmed (BAN)
# bat_or_bowl                       bat
# bb_bf                               1
# runs                                0
# wkts                              0.0
# wicketball_prob                   0.0
# runs_per_ball                     0.0
# opposition                v Australia
# ground                           Pune
# start_date                  11-Nov-23
# overs                            10.0
# mdns                              0.0
# econ                         5.618478
# inns                                1
# 4s                                0.0
# 6s                                0.0
# sr                                0.0
# not_out                           1.0
# mins                              2.0
# Name: 1232, dtype: object

# %% [markdown]
# ## which team took max. no. of wickets

# %%
df.iloc[df["wkts"].idxmax()]
# Out:
# team                                IND
# player             Mohammed Shami (IND)
# bat_or_bowl                        bowl
# bb_bf                                59
# runs                                 57
# wkts                                7.0
# wicketball_prob                0.118644
# runs_per_ball                  0.966102
# opposition                v New Zealand
# ground                         Wankhede
# start_date                    15-Nov-23
# overs                               9.5
# mdns                                0.0
# econ                               5.79
# inns                                  2
# 4s                                  0.0
# 6s                                  0.0
# sr                            83.716596
# not_out                             0.0
# mins                           42.72104
# Name: 1385, dtype: object

# %% [markdown]
# ## which team took min no. of wickets

# %%
df.iloc[df["wkts"].idxmin()]
# Out:
# team                             NZ
# player             DJ Mitchell (NZ)
# bat_or_bowl                    bowl
# bb_bf                             3
# runs                              1
# wkts                            0.0
# wicketball_prob                 0.0
# runs_per_ball              0.333333
# opposition               v Pakistan
# ground                    Bengaluru
# start_date                 4-Nov-23
# overs                           0.3
# mdns                            0.0
# econ                            2.0
# inns                              2
# 4s                              0.0
# 6s                              0.0
# sr                        83.716596
# not_out                         0.0
# mins                       42.72104
# Name: 323, dtype: object

# %% [markdown]
# ## 2)

# %%
df["player"].mode()
# Out:
# 0    GD Phillips (NZ)
# 1     R Ravindra (NZ)
# Name: player, dtype: object

# %%
df["player"].value_counts()
# Out:
# GD Phillips (NZ)    19
# R Ravindra (NZ)     19
# A Dutt (NED)        18
# AU Rashid (ENG)     18
# PJ Cummins (AUS)    18
#                     ..
# LB Williams (SA)     1
# R Ashwin (IND)       1
# SA Abbott (AUS)      1
# AT Carey (AUS)       1
# SA Yadav(IND)        1
# Name: player, Length: 152, dtype: int64

# %%
df.iloc[df["6s"].idxmax()]
# Out:
# team                              PAK
# player             Fakhar Zaman (PAK)
# bat_or_bowl                       bat
# bb_bf                              81
# runs                              126
# wkts                              0.0
# wicketball_prob                   0.0
# runs_per_ball                  1.5555
# opposition              v New Zealand
# ground                      Bengaluru
# start_date                   4-Nov-23
# overs                            10.0
# mdns                              0.0
# econ                         8.949185
# inns                                2
# 4s                                8.0
# 6s                               11.0
# sr                             155.55
# not_out                           1.0
# mins                            103.0
# Name: 511, dtype: object

# %%
df.iloc[df["4s"].idxmax()]
# Out:
# team                            AUS
# player             GJ Maxwell (AUS)
# bat_or_bowl                     bat
# bb_bf                           128
# runs                            201
# wkts                            0.0
# wicketball_prob                 0.0
# runs_per_ball                1.5703
# opposition            v Afghanistan
# ground                     Wankhede
# start_date                 7-Nov-23
# overs                          10.0
# mdns                            0.0
# econ                        8.99538
# inns                              2
# 4s                             21.0
# 6s                             10.0
# sr                           157.03
# not_out                         1.0
# mins                          181.0
# Name: 501, dtype: object

# %%
df.head()
# Out:
#   team                     player bat_or_bowl  bb_bf  runs  wkts  \
# 0  PAK  Shaheen Shah Afridi (PAK)        bowl     60    45   3.0
# 1  ENG            DJ Willey (ENG)        bowl     60    45   3.0
# 2   NZ              MJ Henry (NZ)        bowl     60    48   3.0
# 3   NZ           LH Ferguson (NZ)        bowl     60    49   3.0
# 4  AFG           Noor Ahmad (AFG)        bowl     60    49   3.0
#
#    wicketball_prob  runs_per_ball      opposition     ground start_date  \
# 0             0.05       0.750000  v South Africa    Chennai  27-Oct-23
# 1             0.05       0.750000         v India    Lucknow  29-Oct-23
# 2             0.05       0.800000       v England  Ahmedabad   5-Oct-23
# 3             0.05       0.816667    v Bangladesh    Chennai  13-Oct-23
# 4             0.05       0.816667      v Pakistan    Chennai  23-Oct-23
#
#    overs  mdns  econ  inns   4s   6s         sr  not_out      mins
# 0   10.0   0.0   4.5     2  0.0  0.0  83.716596      0.0  42.72104
# 1   10.0   2.0   4.5     1  0.0  0.0  83.716596      0.0  42.72104
# 2   10.0   1.0   4.8     1  0.0  0.0  83.716596      0.0  42.72104
# 3   10.0   0.0   4.9     1  0.0  0.0  83.716596      0.0  42.72104
# 4   10.0   0.0   4.9     1  0.0  0.0  83.716596      0.0  42.72104

# %%
bowl = df[(df["bat_or_bowl"]=="bowl") & (df["wkts"]>3) &(df["wicketball_prob"]>0.03 )]

sns.barplot(x=bowl["wkts"],y=bowl["player"],data=bowl)
# Out:
# <Axes: xlabel='wkts', ylabel='player'>

# %%
df["bat_or_bowl"].unique()
x=df["runs"].unique()
x.mean()
df["runs_per_ball"].value_counts()
df["runs_per_ball"].isin([2]).sum()
# Out:
# 11

# %%
bat = df[(df["bat_or_bowl"]=="bat") & (df["runs"]>50) & (df["runs_per_ball"]>1.3) ]

sns.barplot(x=bat["runs"],y=bat["player"],data=bat)
# Out:
# <Axes: xlabel='runs', ylabel='player'>

# %%
sns.lineplot(x=df["runs"],y=df["4s"],data=df)
# Out:
# <Axes: xlabel='runs', ylabel='4s'>

# %%
sns.lineplot(x=df["runs"],y=df["6s"],data=df)
# Out:
# <Axes: xlabel='runs', ylabel='6s'>

# %%
df["ground"].unique()
# Out:
# array(['Chennai', 'Lucknow', 'Ahmedabad', 'Delhi', 'Pune', 'Dharamsala',
#        'Eden Gardens', 'Bengaluru', 'Wankhede', 'Hyderabad'], dtype=object)

# %%
average_runs_per_ground = df.groupby("ground")["runs"].mean().reset_index()
average_runs_per_ground.max()
# Out:
# ground     Wankhede
# runs      37.810811
# dtype: object

# %%
plt.figure(figsize=(12, 6))
plt.plot(average_runs_per_ground["ground"], average_runs_per_ground["runs"], color='skyblue')
plt.xlabel('Ground')
plt.ylabel('Average Runs')
plt.title('Average Runs on Each Ground')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
df["ground"].unique()
# Out:
# array(['Chennai', 'Lucknow', 'Ahmedabad', 'Delhi', 'Pune', 'Dharamsala',
#        'Eden Gardens', 'Bengaluru', 'Wankhede', 'Hyderabad'], dtype=object)

# %%
ax=sns.lineplot(x=average_runs_per_ground["ground"], y=average_runs_per_ground["runs"],data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title("Avearage no. of runs")
plt.show()
# Out:
# <ipython-input-321-34aad3a7d929>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
average_runs_per_opposition = df.groupby("opposition")["runs"].mean().reset_index()
average_runs_per_opposition
# Out:
#        opposition       runs
# 0   v Afghanistan  31.823077
# 1     v Australia  34.342105
# 2    v Bangladesh  35.601626
# 3       v England  33.007463
# 4         v India  28.987952
# 5   v Netherlands  31.746269
# 6   v New Zealand  37.687500
# 7      v Pakistan  34.374101
# 8  v South Africa  30.957055
# 9     v Sri Lanka  35.138211

# %%
ax=sns.lineplot(x=average_runs_per_opposition["opposition"], y=average_runs_per_opposition["runs"],data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-280-1f543cfaa003>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
average_wkts_per_opposition = df.groupby("opposition")["wkts"].mean().reset_index()
# Out:
#        opposition      wkts
# 0   v Afghanistan  0.446154
# 1     v Australia  0.493421
# 2    v Bangladesh  0.577236
# 3       v England  0.604478
# 4         v India  0.265060
# 5   v Netherlands  0.582090
# 6   v New Zealand  0.437500
# 7      v Pakistan  0.460432
# 8  v South Africa  0.441718
# 9     v Sri Lanka  0.577236

# %%
ax=sns.lineplot(x=average_wkts_per_opposition["opposition"], y=average_wkts_per_opposition["wkts"],data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-291-d93fcbfde012>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
## so other teams are taking less wickets vs india..so it indicates india is performing well.

# %%
average_sixes_per_opposition = df.groupby("opposition")["4s"].mean().reset_index()
average_sixes_per_opposition
# Out:
#        opposition        4s
# 0   v Afghanistan  1.415385
# 1     v Australia  1.473684
# 2    v Bangladesh  1.804878
# 3       v England  1.582090
# 4         v India  1.066265
# 5   v Netherlands  1.850746
# 6   v New Zealand  1.555556
# 7      v Pakistan  1.812950
# 8  v South Africa  1.411043
# 9     v Sri Lanka  1.878049

# %%
ax=sns.lineplot(x=average_sixes_per_opposition["opposition"], y=average_sixes_per_opposition["4s"],data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-298-cbb329caf02a>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
team_stats = df.groupby('team').agg({
    'runs': 'sum',
    'wkts': 'sum'
}).reset_index()

team_stats = team_stats.sort_values(by='runs', ascending=False)
#team_stats = team_stats.sort_values(by='wkts', ascending=False)
team_stats
# Out:
#   team  runs  wkts
# 6   NZ  5376  71.0
# 1  AUS  5234  77.0
# 8   SA  5097  88.0
# 7  PAK  4786  65.0
# 4  IND  4783  94.0
# 3  ENG  4396  65.0
# 9   SL  4366  50.0
# 2  BAN  4358  51.0
# 5  NED  4268  63.0
# 0  AFG  4134  53.0

# %%
team_stats = df.groupby('team').agg({
    'runs': 'sum',
    'wkts': 'sum'
}).reset_index()

#team_stats = team_stats.sort_values(by='runs', ascending=False)
team_stats = team_stats.sort_values(by='wkts', ascending=False)
team_stats
# Out:
#   team  runs  wkts
# 4  IND  4783  94.0
# 8   SA  5097  88.0
# 1  AUS  5234  77.0
# 6   NZ  5376  71.0
# 3  ENG  4396  65.0
# 7  PAK  4786  65.0
# 5  NED  4268  63.0
# 0  AFG  4134  53.0
# 2  BAN  4358  51.0
# 9   SL  4366  50.0

# %%
team_stats = df.groupby('team').agg({
    'runs': 'sum',
    'wkts': 'sum'
}).reset_index()

team_stats
# Out:
#   team  runs  wkts
# 0  AFG  4134  53.0
# 1  AUS  5234  77.0
# 2  BAN  4358  51.0
# 3  ENG  4396  65.0
# 4  IND  4783  94.0
# 5  NED  4268  63.0
# 6   NZ  5376  71.0
# 7  PAK  4786  65.0
# 8   SA  5097  88.0
# 9   SL  4366  50.0

# %%
df.iloc[df["mdns"].idxmax()]
# Out:
# team                                    BAN
# player             Mehidy Hasan Miraz (BAN)
# bat_or_bowl                            bowl
# bb_bf                                    54
# runs                                     25
# wkts                                    3.0
# wicketball_prob                    0.055556
# runs_per_ball                      0.462963
# opposition                    v Afghanistan
# ground                           Dharamsala
# start_date                         7-Oct-23
# overs                                   9.0
# mdns                                    3.0
# econ                                   2.77
# inns                                      1
# 4s                                      0.0
# 6s                                      0.0
# sr                                83.716596
# not_out                                 0.0
# mins                               42.72104
# Name: 78, dtype: object
